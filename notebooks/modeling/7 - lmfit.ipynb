# %% [markdown]
# # lmfit

# %% [markdown]
# https://lmfit.github.io/lmfit-py/model.html

# %% [markdown]
# ## Init

# %%
from numpy import exp, linspace, random
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
from lmfit import Model
# %matplotlib inline 
import mpld3
#mpld3.enable_notebook()

# %%
SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('figure', figsize=(13, 8))  
plt.rc('lines', linewidth=2)

# %% [markdown]
# ## Function & Data

# %%
def gaussian(x, amp, cen, wid):
    return amp * exp(-(x-cen)**2 / wid)

# %%
x = linspace(-10, 10, 101)
y = gaussian(x, 2.33, 0.21, 1.51) + random.normal(0, 0.2, x.size)

f, ax = plt.subplots(1, 1)
ax.plot(x, y, marker='o', linestyle='', color='#00b3b3', label='Data')

plt.show()

# %% [markdown]
# ## curve_fit

# %% [markdown]
# lmfit is similar to curve_fit where it uses least squares and it also solves similar problem. However, it's more flexible, requires more work for simple fitting, and has different interface. Here's how it's done with curve_fit for example.

# %%
init_vals = [1, 0, 1]  # for [amp, cen, wid]
best_vals, covar = curve_fit(gaussian, x, y, p0=init_vals)
print('best_vals: {}'.format(best_vals))
# Out:
# best_vals: [2.42007416 0.2520887  1.41693168]

# %%
f, ax = plt.subplots(1, 1)
ax.plot(x, y, marker='o', linestyle='', color='#00b3b3', label='Data')
ax.plot(x, gaussian(x, *best_vals), linestyle='--', linewidth=2, color='black')

plt.show()

# %% [markdown]
# ## lmfit

# %% [markdown]
# ### Model

# %% [markdown]
# lmfit requires the function to be wrapped in a model.

# %%
gmodel = Model(gaussian)
gmodel
# Out:
# <lmfit.Model: Model(gaussian)>

# %%
print('parameter names: {}'.format(gmodel.param_names))
print('independent variables: {}'.format(gmodel.independent_vars))
# Out:
# parameter names: ['amp', 'cen', 'wid']
# independent variables: ['x']

# %% [markdown]
# ### params

# %% [markdown]
# You should make params

# %%
params = gmodel.make_params()
params
# Out:
# Parameters([('amp', <Parameter 'amp', value=-inf, bounds=[-inf:inf]>),
#             ('cen', <Parameter 'cen', value=-inf, bounds=[-inf:inf]>),
#             ('wid', <Parameter 'wid', value=-inf, bounds=[-inf:inf]>)])

# %% [markdown]
# You can set initial values right away when making params.

# %%
params = gmodel.make_params(cen=5, amp=200, wid=1)
params
# Out:
# Parameters([('amp', <Parameter 'amp', value=200, bounds=[-inf:inf]>),
#             ('cen', <Parameter 'cen', value=5, bounds=[-inf:inf]>),
#             ('wid', <Parameter 'wid', value=1, bounds=[-inf:inf]>)])

# %% [markdown]
# ### eval

# %% [markdown]
# You can have the model evaluate the given parameters. You can use the params object.

# %%
x_eval = linspace(0, 10, 201)
y_eval = gmodel.eval(params, x=x_eval)
y_eval[:5]
# Out:
# array([2.77758877e-09, 4.56803532e-09, 7.47514266e-09, 1.21713302e-08,
#        1.97190112e-08])

# %% [markdown]
# Or specify the values with keyword args.

# %%
y_eval = gmodel.eval(x=x_eval, cen=5, amp=200, wid=1)
y_eval[:5]
# Out:
# array([2.77758877e-09, 4.56803532e-09, 7.47514266e-09, 1.21713302e-08,
#        1.97190112e-08])

# %% [markdown]
# ### fit

# %% [markdown]
# Fitting the model to data is rather simple.

# %%
params = gmodel.make_params(cen=1, amp=1, wid=2.0)
params
# Out:
# Parameters([('amp', <Parameter 'amp', value=1, bounds=[-inf:inf]>),
#             ('cen', <Parameter 'cen', value=1, bounds=[-inf:inf]>),
#             ('wid', <Parameter 'wid', value=2.0, bounds=[-inf:inf]>)])

# %%
result = gmodel.fit(y, params, x=x)
result
# Out:
# <h2> Model</h2> Model(gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>34</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 4.19417978</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.04279775</td><td></td></tr><tr><td>Akaike info crit.</td><td>-315.323695</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-307.478333</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.42008091 </td><td>  0.09276736 </td><td> (3.83%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> cen </td><td>  0.25208722 </td><td>  0.03725818 </td><td> (14.78%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> wid </td><td>  1.41691588 </td><td>  0.12544648 </td><td> (8.85%) </td><td> 2.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>wid</td><td>-0.5774</td></tr></table>

# %% [markdown]
# Or, like before, with keyword args.

# %%
result = gmodel.fit(y, x=x, cen=1, amp=1, wid=2.0)
result
# Out:
# <h2> Model</h2> Model(gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>34</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 4.19417978</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.04279775</td><td></td></tr><tr><td>Akaike info crit.</td><td>-315.323695</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-307.478333</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.42008091 </td><td>  0.09276736 </td><td> (3.83%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> cen </td><td>  0.25208722 </td><td>  0.03725818 </td><td> (14.78%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> wid </td><td>  1.41691588 </td><td>  0.12544648 </td><td> (8.85%) </td><td> 2.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>wid</td><td>-0.5774</td></tr></table>

# %%
plt.plot(x, y, 'bo')
plt.plot(x, result.init_fit, 'k--', label='initial fit')
plt.plot(x, result.best_fit, 'r-', label='best fit')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## guess

# %% [markdown]
# lmfit can guess intial value for some built-in models. Not this one though

# %%
gmodel.guess(y)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-21-12c038ff9c7b> in <module>
# ----> 1 gmodel.guess(y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in guess(self, data, **kws)
#     725         cname = self.__class__.__name__
#     726         msg = 'guess() not implemented for %s' % cname
# --> 727         raise NotImplementedError(msg)
#     728
#     729     def _residual(self, params, data, weights, **kwargs):
#
# NotImplementedError: guess() not implemented for Model

# %% [markdown]
# ## set_param_hint

# %% [markdown]
# You can set initial, minimum, and maximum value for a parameter. You can also set if it can be varied or not. Parameters with vary=false will not be fitted. You can also set an expression to for it to guess. For example, if you want A to be always half of B, for A, expr="0.5*B".

# %%
gmodel.set_param_hint(
    name="cen",
    value=6.5,
    min=0.01,
    max=10,
    vary=True
)
gmodel.set_param_hint(
    name="amp",
    value=10,
    min=0.01,
    max=1000,
    expr="min(amp, cen)",
    vary=True
)
gmodel.set_param_hint(
    name="wid",
    value=2.0,
    min=0.01,
    max=10,
    vary=True
)
gmodel.print_param_hints()
# Out:
# Name     Value      Min      Max     Vary    Expr
# amp        10     0.01     1000     True    min(amp, cen)
# cen       6.5     0.01       10     True
# wid         2     0.01       10     True

# %%
params = gmodel.make_params()
params
# Out:
# Parameters([('amp',
#              <Parameter 'amp', value=6.5, bounds=[0.01:1000], expr='min(amp, cen)'>),
#             ('cen', <Parameter 'cen', value=6.5, bounds=[0.01:10]>),
#             ('wid', <Parameter 'wid', value=2.0, bounds=[0.01:10]>)])

# %% [markdown]
# Sometimes params from make_params is not updating after you set hints. Weird.

# %%
result = gmodel.fit(y, params, x=x)
result
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-24-e3ffc34a9ec5> in <module>
# ----> 1 result = gmodel.fit(y, params, x=x)
#       2 result
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, calc_covar, max_nfev, **kwargs)
#    1011                              nan_policy=self.nan_policy, calc_covar=calc_covar,
#    1012                              max_nfev=max_nfev, **fit_kws)
# -> 1013         output.fit(data=data, weights=weights)
#    1014         output.components = self.components
#    1015         return output
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1364         self.userkws.update(kwargs)
#    1365         self.init_fit = self.model.eval(params=self.params, **self.userkws)
# -> 1366         _ret = self.minimize(method=self.method)
#    1367
#    1368         for attr in dir(_ret):
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    2283                         val.lower().startswith(user_method)):
#    2284                     kwargs['method'] = val
# -> 2285         return function(**kwargs)
#    2286
#    2287
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\minimizer.py in leastsq(self, params, max_nfev, **kws)
#    1615
#    1616         """
# -> 1617         result = self.prepare_fit(params=params)
#    1618         result.method = 'leastsq'
#    1619         result.nfev -= 2  # correct for "pre-fit" initialization/checks
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\minimizer.py in prepare_fit(self, params)
#     700         result.var_names = []  # note that this *does* belong to self...
#     701         result.init_vals = []
# --> 702         result.params.update_constraints()
#     703         result.nfev = 0
#     704         result.call_kws = {}
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\parameter.py in update_constraints(self)
#     238
#     239         for name in requires_update:
# --> 240             _update_param(name)
#     241
#     242     def pretty_repr(self, oneline=False):
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\parameter.py in _update_param(name)
#     233             for dep in par._expr_deps:
#     234                 if dep in updated_tracker:
# --> 235                     _update_param(dep)
#     236             self._asteval.symtable[name] = par.value
#     237             updated_tracker.discard(name)
#
# ... last 1 frames repeated, from the frame below ...
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\parameter.py in _update_param(name)
#     233             for dep in par._expr_deps:
#     234                 if dep in updated_tracker:
# --> 235                     _update_param(dep)
#     236             self._asteval.symtable[name] = par.value
#     237             updated_tracker.discard(name)
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# What the heck.

# %% [markdown]
# ## result

# %% [markdown]
# ### Confident Interval

# %% [markdown]
# Calculate the confidence intervals for the variable parameters. Idk why it's like this, what this means, or how to use this.

# %%
result.conf_interval()
# Out:
# OrderedDict([('amp',
#               [(0.9973002039367398, 2.1424173997016944),
#                (0.9544997361036416, 2.236186197383466),
#                (0.6826894921370859, 2.3283187725682435),
#                (0.0, 2.4200809112942876),
#                (0.6826894921370859, 2.5129832445103),
#                (0.9544997361036416, 2.608475371787394),
#                (0.9973002039367398, 2.7082311418605634)]),
#              ('cen',
#               [(0.9973002039367398, 0.1366946657497405),
#                (0.9544997361036416, 0.17637471672428806),
#                (0.6826894921370859, 0.214596696063242),
#                (0.0, 0.2520872172265235),
#                (0.6826894921370859, 0.28953573058985144),
#                (0.9544997361036416, 0.32763197506183694),
#                (0.9973002039367398, 0.3670941501209661)]),
#              ('wid',
#               [(0.9973002039367398, 1.0870169324745302),
#                (0.9544997361036416, 1.190453525855961),
#                (0.6826894921370859, 1.2997021269380258),
#                (0.0, 1.4169158816718372),
#                (0.6826894921370859, 1.5448226289051752),
#                (0.9544997361036416, 1.68693846199306),
#                (0.9973002039367398, 1.8480843200321586)])])

# %%
print(result.ci_report())
# Out:
#         99.73%    95.45%    68.27%    _BEST_    68.27%    95.45%    99.73%
#  amp:  -0.27766  -0.18389  -0.09176   2.42008  +0.09290  +0.18839  +0.28815
#  cen:  -0.11539  -0.07571  -0.03749   0.25209  +0.03745  +0.07554  +0.11501
#  wid:  -0.32990  -0.22646  -0.11721   1.41692  +0.12791  +0.27002  +0.43117

# %% [markdown]
# ### eval_uncertainty

# %% [markdown]
# Evaluate the uncertainty of the model function.
#
# This can be used to give confidence bands for the model from the uncertainties in the best-fit parameters.
#
# The value of sigma is number of sigma values, and is converted to a probability. Values of 1, 2, or 3 give probabilities of 0.6827, 0.9545, and 0.9973, respectively. If the sigma value is < 1, it is interpreted as the probability itself. That is, sigma=1 and sigma=0.6827 will give the same results, within precision errors.

# %%
result.eval_uncertainty(sigma=0.9545)
# Out:
# array([3.70412902e-31, 5.97935661e-30, 9.13359783e-29, 1.32015957e-27,
#        1.80544348e-26, 2.33608021e-25, 2.85962431e-24, 3.31143325e-23,
#        3.62722546e-22, 3.75792016e-21, 3.68209536e-20, 3.41172510e-19,
#        2.98908636e-18, 2.47593376e-17, 1.93875551e-16, 1.43494212e-15,
#        1.00372150e-14, 6.63431251e-14, 4.14299809e-13, 2.44397947e-12,
#        1.36165657e-11, 7.16379110e-11, 3.55824619e-10, 1.66821893e-09,
#        7.38062766e-09, 3.08069041e-08, 1.21282908e-07, 4.50214832e-07,
#        1.57531867e-06, 5.19387003e-06, 1.61293429e-05, 4.71578757e-05,
#        1.29744505e-04, 3.35720117e-04, 8.16471343e-04, 1.86491247e-03,
#        3.99719995e-03, 8.03144669e-03, 1.51095442e-02, 2.65770408e-02,
#        4.36327970e-02, 6.67230039e-02, 9.48061163e-02, 1.24825337e-01,
#        1.51884567e-01, 1.70575281e-01, 1.77525215e-01, 1.74451057e-01,
#        1.69378542e-01, 1.71464188e-01, 1.80641103e-01, 1.87573165e-01,
#        1.85165677e-01, 1.75856406e-01, 1.69268081e-01, 1.71380942e-01,
#        1.76797516e-01, 1.75703310e-01, 1.62962088e-01, 1.39644006e-01,
#        1.10476669e-01, 8.08712605e-02, 5.49295860e-02, 3.47091290e-02,
#        2.04496532e-02, 1.12552237e-02, 5.79604889e-03, 2.79634322e-03,
#        1.26534522e-03, 5.37519229e-04, 2.14532330e-04, 8.05016745e-05,
#        2.84178592e-05, 9.44237291e-06, 2.95445317e-06, 8.70883895e-07,
#        2.41932009e-07, 6.33612368e-08, 1.56489571e-08, 3.64587314e-09,
#        8.01466446e-10, 1.66280585e-10, 3.25662290e-11, 6.02218143e-12,
#        1.05168434e-12, 1.73476880e-13, 2.70331664e-14, 3.98035060e-15,
#        5.53835232e-16, 7.28343859e-17, 9.05413593e-18, 1.06406138e-18,
#        1.18235124e-19, 1.24232221e-20, 1.23445276e-21, 1.16013546e-22,
#        1.03127739e-23, 8.67182640e-25, 6.89837676e-26, 5.19176272e-27,
#        3.69693796e-28])

# %%
len(result.eval_uncertainty()) == len(x)
# Out:
# True

# %%
dely = result.eval_uncertainty(sigma=3)
plt.plot(x, y, 'bo')
plt.plot(x, result.init_fit, 'k--', label='initial fit')
plt.plot(x, result.best_fit, 'r-', label='best fit')
plt.fill_between(x, result.best_fit-dely, result.best_fit+dely, color="#ABABAB", label='3-$\sigma$ uncertainty band')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### plot

# %%
result.plot(show_init=True)
# Out:
# (<Figure size 936x936 with 2 Axes>, GridSpec(2, 1, height_ratios=[1, 4]))

# %%
result.plot_fit(show_init=True)
plt.show()

# %%
result.plot_residuals()
plt.show()

# %% [markdown]
# ### best_values

# %% [markdown]
# Parameter values for best fit

# %%
result.best_values
# Out:
# {'amp': 2.4200809112942876,
#  'cen': 0.2520872172265235,
#  'wid': 1.4169158816718372}

# %% [markdown]
# ### best_fit

# %% [markdown]
# y value of the best fit

# %%
result.best_fit
# Out:
# array([1.47344353e-32, 2.58825686e-31, 4.29695395e-30, 6.74207336e-29,
#        9.99782881e-28, 1.40119109e-26, 1.85595947e-25, 2.32337364e-24,
#        2.74883755e-23, 3.07367922e-22, 3.24823511e-21, 3.24426125e-20,
#        3.06241210e-19, 2.73206415e-18, 2.30354979e-17, 1.83562414e-16,
#        1.38244980e-15, 9.83998473e-15, 6.61940463e-14, 4.20845689e-13,
#        2.52875226e-12, 1.43604859e-11, 7.70746276e-11, 3.90960772e-10,
#        1.87427961e-09, 8.49209856e-09, 3.63642906e-08, 1.47168432e-07,
#        5.62903119e-07, 2.03484857e-06, 6.95200354e-06, 2.24474660e-05,
#        6.85021353e-05, 1.97569702e-04, 5.38537597e-04, 1.38736636e-03,
#        3.37789186e-03, 7.77284080e-03, 1.69041466e-02, 3.47445090e-02,
#        6.74929725e-02, 1.23911148e-01, 2.15001581e-01, 3.52575700e-01,
#        5.46440082e-01, 8.00409376e-01, 1.10805479e+00, 1.44973877e+00,
#        1.79265914e+00, 2.09500534e+00, 2.31393948e+00, 2.41545143e+00,
#        2.38300015e+00, 2.22192441e+00, 1.95800564e+00, 1.63071492e+00,
#        1.28357603e+00, 9.54870781e-01, 6.71347007e-01, 4.46096647e-01,
#        2.80149795e-01, 1.66276590e-01, 9.32720144e-02, 4.94482644e-02,
#        2.47759433e-02, 1.17324522e-02, 5.25081642e-03, 2.22097836e-03,
#        8.87853408e-04, 3.35442167e-04, 1.19777017e-04, 4.04211606e-05,
#        1.28920955e-05, 3.88613334e-06, 1.10711142e-06, 2.98087943e-07,
#        7.58537298e-08, 1.82426917e-08, 4.14648736e-09, 8.90740547e-10,
#        1.80842935e-10, 3.47001474e-11, 6.29275092e-12, 1.07852251e-12,
#        1.74701781e-13, 2.67451415e-14, 3.86965206e-15, 5.29149491e-16,
#        6.83855426e-17, 8.35275340e-18, 9.64216306e-19, 1.05195880e-19,
#        1.08468202e-20, 1.05702583e-21, 9.73527459e-23, 8.47403514e-24,
#        6.97126777e-25, 5.42016762e-26, 3.98284237e-27, 2.76600505e-28,
#        1.81548334e-29])

# %%
len(result.best_fit) == len(x)
# Out:
# True

# %% [markdown]
# ### covar

# %% [markdown]
# Covarience, used to calculate stdev. Just like 2nd output of curve_fit

# %%
result.covar
# Out:
# array([[ 8.60578363e-03,  3.83625692e-11, -6.71882110e-03],
#        [ 3.83625692e-11,  1.38817196e-03, -3.87895548e-11],
#        [-6.71882110e-03, -3.87895548e-11,  1.57368203e-02]])

# %% [markdown]
# ### redchi

# %% [markdown]
# Floating point reduced chi-square statistic (see MinimizerResult – the optimization result).

# %%
result.redchi
# Out:
# 0.04279775290657867

# %% [markdown]
# ### residual

# %% [markdown]
# residual values of the best fit and data

# %%
result.residual
# Out:
# array([-0.1220468 ,  0.19239475,  0.31469557,  0.44803278, -0.29899557,
#         0.32097468,  0.25613611, -0.27149972,  0.00836657, -0.12914337,
#         0.04779881, -0.01853212, -0.21301161,  0.0885093 , -0.0389755 ,
#         0.3861639 ,  0.07012718,  0.12364261,  0.37944263, -0.12871014,
#         0.36436443,  0.25966323,  0.13052734,  0.13965616, -0.34097703,
#        -0.21064369, -0.28050288,  0.37189966,  0.00482447, -0.26099312,
#        -0.27653305,  0.09065333, -0.17727282,  0.28555278,  0.11405388,
#         0.0170426 ,  0.1555191 ,  0.17215651,  0.06447764, -0.26980003,
#        -0.0170388 ,  0.36304264, -0.03270038, -0.05711021, -0.31203916,
#         0.04439494,  0.29969083, -0.08744749, -0.04991269,  0.06614877,
#        -0.4163303 ,  0.35872865,  0.09443056,  0.08841664, -0.12270493,
#        -0.01465678, -0.26282572, -0.14329051,  0.30098335,  0.24231445,
#        -0.17753223,  0.14002973, -0.09179848,  0.34817973, -0.30646287,
#        -0.13397021,  0.07094145,  0.05582668,  0.1864634 ,  0.1225054 ,
#         0.23503749, -0.17680042,  0.03614398,  0.10407186,  0.13108614,
#        -0.04950992, -0.09952582, -0.06533274,  0.14887338,  0.02774107,
#         0.08592052,  0.11952549, -0.18619073,  0.11077283,  0.03421328,
#         0.18988856, -0.17208793,  0.08194125,  0.11696896, -0.19318856,
#        -0.05406561, -0.26237121,  0.04611742, -0.40004896, -0.05668364,
#        -0.08565712,  0.09202379, -0.12748322,  0.10243704, -0.05188917,
#         0.43362417])

# %%
len(result.residual) == len(x)
# Out:
# True

# %% [markdown]
# ## Composite Model

# %% [markdown]
# With lmfit, you can make composite model simply. For example, I want to make line+gaussian.

# %%
def gaussian_plus_line(x, amp, cen, wid, slope, intercept):
    """line + 1-d gaussian"""

    gauss = amp * exp(-(x-cen)**2 / wid)
    line = slope*x + intercept
    return gauss + line

# %%
mod = Model(gaussian_plus_line)
print('parameter names: {}'.format(mod.param_names))
print('independent variables: {}'.format(mod.independent_vars))
# Out:
# parameter names: ['amp', 'cen', 'wid', 'slope', 'intercept']
# independent variables: ['x']

# %% [markdown]
# But we can also make the line model, and combine the models.

# %%
def line(x, slope, intercept):
    """a line"""
    return slope*x + intercept

# %%
mod = Model(gaussian) + Model(line)
print('parameter names: {}'.format(mod.param_names))
print('independent variables: {}'.format(mod.independent_vars))
# Out:
# parameter names: ['amp', 'cen', 'wid', 'slope', 'intercept']
# independent variables: ['x']

# %%
y2 = gaussian_plus_line(x, 2.33, 0.21, 1.51, 1, 1) + random.normal(0, 0.2, x.size)
pars = mod.make_params(amp=1, cen=1, wid=1, slope=0, intercept=1)

result = mod.fit(y2, pars, x=x)

print(result.fit_report())

plt.plot(x, y2, 'bo')
plt.plot(x, result.init_fit, 'k--', label='initial fit')
plt.plot(x, result.best_fit, 'r-', label='best fit')
plt.legend(loc='best')
plt.show()
# Out:
# [[Model]]
#     (Model(gaussian) + Model(line))
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 43
#     # data points      = 101
#     # variables        = 5
#     chi-square         = 3.38137396
#     reduced chi-square = 0.03522265
#     Akaike info crit   = -333.080678
#     Bayesian info crit = -320.005075
# [[Variables]]
#     amp:        2.38419741 +/- 0.08532997 (3.58%) (init = 1)
#     cen:        0.18638437 +/- 0.03447836 (18.50%) (init = 1)
#     wid:        1.42755399 +/- 0.12156719 (8.52%) (init = 1)
#     slope:      0.99591685 +/- 0.00321315 (0.32%) (init = 0)
#     intercept:  0.97622361 +/- 0.02117792 (2.17%) (init = 1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, wid)       = -0.491
#     C(wid, intercept) = -0.295
#     C(amp, intercept) = -0.176

# %% [markdown]
# Individual component models of the composite model can be accessed through eval_components.

# %%
comps = result.eval_components()
comps
# Out:
# OrderedDict([('gaussian',
#               array([6.46316931e-32, 1.09106041e-30, 1.74146296e-29, 2.62809983e-28,
#                      3.75000331e-27, 5.05922063e-26, 6.45353638e-25, 7.78348480e-24,
#                      8.87590359e-23, 9.57002884e-22, 9.75609660e-21, 9.40375082e-20,
#                      8.57014774e-19, 7.38478202e-18, 6.01657352e-17, 4.63471411e-16,
#                      3.37566117e-15, 2.32464651e-14, 1.51362109e-13, 9.31836238e-13,
#                      5.42405638e-12, 2.98518308e-11, 1.55338791e-10, 7.64277453e-10,
#                      3.55536628e-09, 1.56379502e-08, 6.50335526e-08, 2.55715649e-07,
#                      9.50690842e-07, 3.34182335e-06, 1.11068228e-05, 3.49026477e-05,
#                      1.03702465e-04, 2.91327820e-04, 7.73814771e-04, 1.94336442e-03,
#                      4.61459567e-03, 1.03603693e-02, 2.19927225e-02, 4.41412805e-02,
#                      8.37670144e-02, 1.50301502e-01, 2.54985674e-01, 4.09006694e-01,
#                      6.20307777e-01, 8.89500532e-01, 1.20600018e+00, 1.54600435e+00,
#                      1.87385604e+00, 2.14745420e+00, 2.32687886e+00, 2.38388781e+00,
#                      2.30919191e+00, 2.11493204e+00, 1.83144964e+00, 1.49953195e+00,
#                      1.16085677e+00, 8.49696305e-01, 5.88045589e-01, 3.84787042e-01,
#                      2.38063085e-01, 1.39259826e-01, 7.70232462e-02, 4.02791189e-02,
#                      1.99159158e-02, 9.31070950e-03, 4.11554588e-03, 1.72002315e-03,
#                      6.79678159e-04, 2.53941986e-04, 8.97073202e-05, 2.99628714e-05,
#                      9.46239676e-06, 2.82540723e-06, 7.97669757e-07, 2.12925353e-07,
#                      5.37395222e-08, 1.28239673e-08, 2.89343131e-09, 6.17257148e-10,
#                      1.24503412e-10, 2.37442555e-11, 4.28152057e-12, 7.29961050e-13,
#                      1.17669394e-13, 1.79345102e-14, 2.58450692e-15, 3.52150293e-16,
#                      4.53670546e-17, 5.52605610e-18, 6.36432239e-19, 6.93028712e-20,
#                      7.13530365e-21, 6.94601740e-22, 6.39324651e-23, 5.56377051e-24,
#                      4.57803535e-25, 3.56165010e-26, 2.61990495e-27, 1.82214107e-28,
#                      1.19823122e-29])),
#              ('line',
#               array([-8.98294494, -8.78376157, -8.5845782 , -8.38539482, -8.18621145,
#                      -7.98702808, -7.78784471, -7.58866134, -7.38947797, -7.1902946 ,
#                      -6.99111123, -6.79192786, -6.59274449, -6.39356112, -6.19437774,
#                      -5.99519437, -5.796011  , -5.59682763, -5.39764426, -5.19846089,
#                      -4.99927752, -4.80009415, -4.60091078, -4.40172741, -4.20254404,
#                      -4.00336067, -3.80417729, -3.60499392, -3.40581055, -3.20662718,
#                      -3.00744381, -2.80826044, -2.60907707, -2.4098937 , -2.21071033,
#                      -2.01152696, -1.81234359, -1.61316021, -1.41397684, -1.21479347,
#                      -1.0156101 , -0.81642673, -0.61724336, -0.41805999, -0.21887662,
#                      -0.01969325,  0.17949012,  0.37867349,  0.57785687,  0.77704024,
#                       0.97622361,  1.17540698,  1.37459035,  1.57377372,  1.77295709,
#                       1.97214046,  2.17132383,  2.3705072 ,  2.56969057,  2.76887394,
#                       2.96805732,  3.16724069,  3.36642406,  3.56560743,  3.7647908 ,
#                       3.96397417,  4.16315754,  4.36234091,  4.56152428,  4.76070765,
#                       4.95989102,  5.1590744 ,  5.35825777,  5.55744114,  5.75662451,
#                       5.95580788,  6.15499125,  6.35417462,  6.55335799,  6.75254136,
#                       6.95172473,  7.1509081 ,  7.35009148,  7.54927485,  7.74845822,
#                       7.94764159,  8.14682496,  8.34600833,  8.5451917 ,  8.74437507,
#                       8.94355844,  9.14274181,  9.34192518,  9.54110855,  9.74029193,
#                       9.9394753 , 10.13865867, 10.33784204, 10.53702541, 10.73620878,
#                      10.93539215]))])

# %%
plt.plot(x, y2, 'bo')
plt.plot(x, comps['gaussian'], 'k--', label='Gaussian component')
plt.plot(x, comps['line'], 'r--', label='Line component')
plt.show()

# %% [markdown]
# Composite Model was created automatically when using arithmetic operator. It actually supports any binary operator. To use a binary operator other than ‘+’, ‘-‘, ‘*’, or ‘/’ you can explicitly create a CompositeModel with the appropriate binary operator. You can also make a custom binary operator function (f(a, b)).
